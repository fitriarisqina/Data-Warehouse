# %%
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Pemanggilan Data
#
# Pada data netflix terdapat 1 dataset
#  Dan Pada data iMDb terdapat 4 dataset

# %%
netflix_titles=pd.read_csv("./netflix_titles.csv")
netflix_titles
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7785                NaN                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
#                                                 country          date_added  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                                NaN  September 25, 2020
# 7785                                          Australia    October 31, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7784          2019  TV-MA     44 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]

# %%
netflix.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
title=pd.read_csv("./title.csv")
title
# Out:
#        imdb_title_id  ordering imdb_name_id         category    job  \
# 0          tt0000009         1    nm0063086          actress    NaN
# 1          tt0000009         2    nm0183823            actor    NaN
# 2          tt0000009         3    nm1309758            actor    NaN
# 3          tt0000009         4    nm0085156         director    NaN
# 4          tt0000574         1    nm0846887          actress    NaN
# ...              ...       ...          ...              ...    ...
# 835508     tt9914942         6    nm3678448           writer    NaN
# 835509     tt9914942         7    nm9361716           writer  novel
# 835510     tt9914942         8    nm2262072         composer    NaN
# 835511     tt9914942         9    nm1966322  cinematographer    NaN
# 835512     tt9914942        10    nm0739828           editor    NaN
#
#                                                characters
# 0                ["Miss Geraldine Holbrook (Miss Jerry)"]
# 1                                        ["Mr. Hamilton"]
# 2       ["Chauncey Depew - the Director of the New Yor...
# 3                                                     NaN
# 4                                          ["Kate Kelly"]
# ...                                                   ...
# 835508                                                NaN
# 835509                                                NaN
# 835510                                                NaN
# 835511                                                NaN
# 835512                                                NaN
#
# [835513 rows x 6 columns]

# %%
title.head()
# Out:
#   imdb_title_id  ordering imdb_name_id  category  job  \
# 0     tt0000009         1    nm0063086   actress  NaN
# 1     tt0000009         2    nm0183823     actor  NaN
# 2     tt0000009         3    nm1309758     actor  NaN
# 3     tt0000009         4    nm0085156  director  NaN
# 4     tt0000574         1    nm0846887   actress  NaN
#
#                                           characters
# 0           ["Miss Geraldine Holbrook (Miss Jerry)"]
# 1                                   ["Mr. Hamilton"]
# 2  ["Chauncey Depew - the Director of the New Yor...
# 3                                                NaN
# 4                                     ["Kate Kelly"]

# %%
imbd_movies= pd.read_csv("./movies.csv")
imbd_movies
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ...  \
# 0                          Alexander Black  ...
# 1                             Charles Tait  ...
# 2                                Urban Gad  ...
# 3                       Charles L. Gaskill  ...
# 4      Francesco Bertolini, Adolfo Padovan  ...
# ...                                    ...  ...
# 85850               Ludovic Colbeau-Justin  ...
# 85851                      Johan Nijenhuis  ...
# 85852                      Vineesh Aaradya  ...
# 85853                    Ahmet Faik Akinci  ...
# 85854                            Laura Jou  ...
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description avg_vote votes  \
# 0      The adventures of a female reporter in the 1890s.      5.9   154
# 1      True story of notorious Australian outlaw Ned ...      6.1   589
# 2      Two men of high rank are both wooing the beaut...      5.8   188
# 3      The fabled queen of Egypt's affair with Roman ...      5.2   446
# 4      Loosely adapted from Dante's Divine Comedy and...      7.0  2237
# ...                                                  ...      ...   ...
# 85850  A psychiatric hospital patient pretends to be ...      5.3   398
# 85851  A middle-aged veterinary surgeon believes his ...      7.7   724
# 85852                                                NaN      7.9   265
# 85853                                                NaN      6.4   194
# 85854  Pep, a 13-year-old boy, is in love with a girl...      6.7   102
#
#         budget  usa_gross_income worlwide_gross_income metascore  \
# 0          NaN               NaN                   NaN       NaN
# 1       $ 2250               NaN                   NaN       NaN
# 2          NaN               NaN                   NaN       NaN
# 3      $ 45000               NaN                   NaN       NaN
# 4          NaN               NaN                   NaN       NaN
# ...        ...               ...                   ...       ...
# 85850      NaN               NaN             $ 3507171       NaN
# 85851      NaN               NaN             $ 7299062       NaN
# 85852      NaN               NaN                   NaN       NaN
# 85853      NaN               NaN                $ 2833       NaN
# 85854      NaN               NaN               $ 59794       NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    1.0                   2.0
# 1                    7.0                   7.0
# 2                    5.0                   2.0
# 3                   25.0                   3.0
# 4                   31.0                  14.0
# ...                  ...                   ...
# 85850                NaN                   4.0
# 85851                6.0                   4.0
# 85852                NaN                   NaN
# 85853                NaN                   NaN
# 85854                NaN                   2.0
#
# [85855 rows x 22 columns]

# %%
imbd_movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
imbd_names=pd.read_csv("./names.csv")
imbd_names
# Out:
#        imdb_name_id             name               birth_name  height  \
# 0         nm0000001     Fred Astaire  Frederic Austerlitz Jr.   177.0
# 1         nm0000002    Lauren Bacall        Betty Joan Perske   174.0
# 2         nm0000003  Brigitte Bardot          Brigitte Bardot   166.0
# 3         nm0000004     John Belushi        John Adam Belushi   170.0
# 4         nm0000005   Ingmar Bergman     Ernst Ingmar Bergman   179.0
# ...             ...              ...                      ...     ...
# 297700    nm5474275  Sunay Terzioglu          Sunay Terzioglu     NaN
# 297701    nm5909653      Sung Lim Ju              Sung Lim Ju     NaN
# 297702    nm5993616     Coulee Nazha        Gülnezer Bextiyar     NaN
# 297703    nm7634163            Ge Ou                    Ge Ou     NaN
# 297704    nm3834123   Richa Langella           Richa Langella   170.0
#
#                                                       bio  \
# 0       Fred Astaire was born in Omaha, Nebraska, to J...
# 1       Lauren Bacall was born Betty Joan Perske on Se...
# 2       Brigitte Bardot was born on September 28, 1934...
# 3       John Belushi was born in Chicago, Illinois, US...
# 4       Ernst Ingmar Bergman was born July 14, 1918, t...
# ...                                                   ...
# 297700                                                NaN
# 297701                                                NaN
# 297702  Coulee Nazha was born on May 2, 1992 in Urumqi...
# 297703                                                NaN
# 297704  Richa Langella, formerly known as Richa Gangop...
#
#                                             birth_details date_of_birth  \
# 0                    May 10, 1899 in Omaha, Nebraska, USA    1899-05-10
# 1       September 16, 1924 in The Bronx, New York City...    1924-09-16
# 2                     September 28, 1934 in Paris, France    1934-09-28
# 3              January 24, 1949 in Chicago, Illinois, USA    1949-01-24
# 4           July 14, 1918 in Uppsala, Uppsala län, Sweden    1918-07-14
# ...                                                   ...           ...
# 297700                                                NaN           NaN
# 297701                                                NaN           NaN
# 297702             May 2, 1992 in Urumqi, Xinjiang, China    1992-05-02
# 297703                                                NaN           NaN
# 297704                 March 20, 1986 in New Delhi, India    1986-03-20
#
#                                  place_of_birth  \
# 0                          Omaha, Nebraska, USA
# 1       The Bronx, New York City, New York, USA
# 2                                 Paris, France
# 3                        Chicago, Illinois, USA
# 4                  Uppsala, Uppsala län, Sweden
# ...                                         ...
# 297700                                      NaN
# 297701                                      NaN
# 297702                  Urumqi, Xinjiang, China
# 297703                                      NaN
# 297704                         New Delhi, India
#
#                                             death_details date_of_death  \
# 0       June 22, 1987 in Los Angeles, California, USA ...    1987-06-22
# 1       August 12, 2014 in New York City, New York, US...    2014-08-12
# 2                                                     NaN           NaN
# 3       March 5, 1982 in Hollywood, Los Angeles, Calif...    1982-03-05
# 4       July 30, 2007 in Fårö, Gotlands län, Sweden  (...    2007-07-30
# ...                                                   ...           ...
# 297700                                                NaN           NaN
# 297701                                                NaN           NaN
# 297702                                                NaN           NaN
# 297703                                                NaN           NaN
# 297704                                                NaN           NaN
#
#                                    place_of_death  \
# 0                  Los Angeles, California, USA
# 1                  New York City, New York, USA
# 2                                             NaN
# 3       Hollywood, Los Angeles, California, USA
# 4                    Fårö, Gotlands län, Sweden
# ...                                           ...
# 297700                                        NaN
# 297701                                        NaN
# 297702                                        NaN
# 297703                                        NaN
# 297704                                        NaN
#
#                               reason_of_death  \
# 0                                   pneumonia
# 1                                      stroke
# 2                                         NaN
# 3       acute cocaine and heroin intoxication
# 4                              natural causes
# ...                                       ...
# 297700                                    NaN
# 297701                                    NaN
# 297702                                    NaN
# 297703                                    NaN
# 297704                                    NaN
#
#                                            spouses_string  spouses  divorces  \
# 0       Robyn Smith  (27 June 1980 - 22 June 1987) (hi...        2         0
# 1       Jason Robards  (4 July 1961 - 10 September 196...        2         1
# 2       Bernard d'Ormale  (16 August 1992 - present)\n...        4         3
# 3       Judith Belushi-Pisano  (31 December 1976 - 5 M...        1         0
# 4       Ingrid Bergman  (11 November 1971 - 20 May 199...        5         4
# ...                                                   ...      ...       ...
# 297700                                                NaN        0         0
# 297701                                                NaN        0         0
# 297702                                                NaN        0         0
# 297703                                                NaN        0         0
# 297704                        Joe Langella  (? - present)        1         0
#
#         spouses_with_children  children
# 0                           1         2
# 1                           2         3
# 2                           1         1
# 3                           0         0
# 4                           5         8
# ...                       ...       ...
# 297700                      0         0
# 297701                      0         0
# 297702                      0         0
# 297703                      0         0
# 297704                      0         0
#
# [297705 rows x 17 columns]

# %%
imbd_names.head()
# Out:
#   imdb_name_id             name               birth_name  height  \
# 0    nm0000001     Fred Astaire  Frederic Austerlitz Jr.   177.0
# 1    nm0000002    Lauren Bacall        Betty Joan Perske   174.0
# 2    nm0000003  Brigitte Bardot          Brigitte Bardot   166.0
# 3    nm0000004     John Belushi        John Adam Belushi   170.0
# 4    nm0000005   Ingmar Bergman     Ernst Ingmar Bergman   179.0
#
#                                                  bio  \
# 0  Fred Astaire was born in Omaha, Nebraska, to J...
# 1  Lauren Bacall was born Betty Joan Perske on Se...
# 2  Brigitte Bardot was born on September 28, 1934...
# 3  John Belushi was born in Chicago, Illinois, US...
# 4  Ernst Ingmar Bergman was born July 14, 1918, t...
#
#                                        birth_details date_of_birth  \
# 0               May 10, 1899 in Omaha, Nebraska, USA    1899-05-10
# 1  September 16, 1924 in The Bronx, New York City...    1924-09-16
# 2                September 28, 1934 in Paris, France    1934-09-28
# 3         January 24, 1949 in Chicago, Illinois, USA    1949-01-24
# 4      July 14, 1918 in Uppsala, Uppsala län, Sweden    1918-07-14
#
#                             place_of_birth  \
# 0                     Omaha, Nebraska, USA
# 1  The Bronx, New York City, New York, USA
# 2                            Paris, France
# 3                   Chicago, Illinois, USA
# 4             Uppsala, Uppsala län, Sweden
#
#                                        death_details date_of_death  \
# 0  June 22, 1987 in Los Angeles, California, USA ...    1987-06-22
# 1  August 12, 2014 in New York City, New York, US...    2014-08-12
# 2                                                NaN           NaN
# 3  March 5, 1982 in Hollywood, Los Angeles, Calif...    1982-03-05
# 4  July 30, 2007 in Fårö, Gotlands län, Sweden  (...    2007-07-30
#
#                               place_of_death  \
# 0             Los Angeles, California, USA
# 1             New York City, New York, USA
# 2                                        NaN
# 3  Hollywood, Los Angeles, California, USA
# 4               Fårö, Gotlands län, Sweden
#
#                          reason_of_death  \
# 0                              pneumonia
# 1                                 stroke
# 2                                    NaN
# 3  acute cocaine and heroin intoxication
# 4                         natural causes
#
#                                       spouses_string  spouses  divorces  \
# 0  Robyn Smith  (27 June 1980 - 22 June 1987) (hi...        2         0
# 1  Jason Robards  (4 July 1961 - 10 September 196...        2         1
# 2  Bernard d'Ormale  (16 August 1992 - present)\n...        4         3
# 3  Judith Belushi-Pisano  (31 December 1976 - 5 M...        1         0
# 4  Ingrid Bergman  (11 November 1971 - 20 May 199...        5         4
#
#    spouses_with_children  children
# 0                      1         2
# 1                      2         3
# 2                      1         1
# 3                      0         0
# 4                      5         8

# %%
imbd_ratings=pd.read_csv("./ratings.csv")
imbd_ratings
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0         tt0000009                    5.9          154        5.9
# 1         tt0000574                    6.1          589        6.3
# 2         tt0001892                    5.8          188        6.0
# 3         tt0002101                    5.2          446        5.3
# 4         tt0002130                    7.0         2237        6.9
# ...             ...                    ...          ...        ...
# 85850     tt9908390                    5.3          398        5.5
# 85851     tt9911196                    7.7          724        7.9
# 85852     tt9911774                    7.9          265        7.8
# 85853     tt9914286                    6.4          194        9.4
# 85854     tt9914942                    6.7          102        6.8
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        12        4       10       43       28  ...
# 1              6.0        57       18       58      137      139  ...
# 2              6.0         6        6       17       44       52  ...
# 3              5.0        15        8       16       62       98  ...
# 4              7.0       210      225      436      641      344  ...
# ...            ...       ...      ...      ...      ...      ...  ...
# 85850          6.0        13        9       26       65      104  ...
# 85851          8.0        65      139      288      170       42  ...
# 85852          8.0        63       29       61       61       31  ...
# 85853         10.0       176        0        2        2        1  ...
# 85854          7.0         4        4       21       35       27  ...
#
#        females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 0                         5.7                 13.0                     4.5
# 1                         6.2                 23.0                     6.6
# 2                         5.8                  4.0                     6.8
# 3                         5.5                 14.0                     6.1
# 4                         7.3                 82.0                     7.4
# ...                       ...                  ...                     ...
# 85850                     5.7                 11.0                     5.0
# 85851                     8.0                 47.0                     7.3
# 85852                     NaN                  NaN                     NaN
# 85853                     NaN                  NaN                     7.0
# 85854                     6.8                  4.0                     7.5
#
#        females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 0                      4.0                    5.7                  34.0
# 1                     14.0                    6.4                  66.0
# 2                      7.0                    5.4                  32.0
# 3                     21.0                    4.9                  57.0
# 4                     77.0                    6.9                 139.0
# ...                    ...                    ...                   ...
# 85850                  2.0                    5.5                  12.0
# 85851                 30.0                    7.0                   6.0
# 85852                  NaN                    1.0                   1.0
# 85853                  1.0                    4.0                   3.0
# 85854                  4.0                    7.0                   4.0
#
#        us_voters_rating  us_voters_votes  non_us_voters_rating  \
# 0                   6.4             51.0                   6.0
# 1                   6.0             96.0                   6.2
# 2                   6.2             31.0                   5.9
# 3                   5.5            207.0                   4.7
# 4                   7.0            488.0                   7.0
# ...                 ...              ...                   ...
# 85850               6.3             22.0                   5.3
# 85851               6.8             13.0                   7.7
# 85852               NaN              NaN                   2.0
# 85853               1.7              5.0                   5.8
# 85854               6.7             13.0                   6.7
#
#        non_us_voters_votes
# 0                     70.0
# 1                    331.0
# 2                    123.0
# 3                    105.0
# 4                   1166.0
# ...                    ...
# 85850                214.0
# 85851                388.0
# 85852                  2.0
# 85853                  5.0
# 85854                 60.0
#
# [85855 rows x 49 columns]

# %%
imbd_ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
#    females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 0                 13.0                     4.5                  4.0
# 1                 23.0                     6.6                 14.0
# 2                  4.0                     6.8                  7.0
# 3                 14.0                     6.1                 21.0
# 4                 82.0                     7.4                 77.0
#
#    top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 0                    5.7                  34.0               6.4
# 1                    6.4                  66.0               6.0
# 2                    5.4                  32.0               6.2
# 3                    4.9                  57.0               5.5
# 4                    6.9                 139.0               7.0
#
#    us_voters_votes  non_us_voters_rating  non_us_voters_votes
# 0             51.0                   6.0                 70.0
# 1             96.0                   6.2                331.0
# 2             31.0                   5.9                123.0
# 3            207.0                   4.7                105.0
# 4            488.0                   7.0               1166.0
#
# [5 rows x 49 columns]

# %% [markdown]
# Kolom Penting

# %%
netflix_titles.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_titles = netflix_titles[['type','title','country','release_year']]
netflix_titles = netflix_titles.rename(columns={'release_year':'year'})

# %%
imbd_movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
imbd_movies = imbd_movies[['imdb_title_id','year','title','genre','votes','avg_vote','budget']]

# %%
imbd_ratings.columns
# Out:
# Index(['imdb_title_id', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6',
#        'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1',
#        'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
#        'females_allages_votes', 'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
#        'females_45age_avg_vote', 'females_45age_votes',
#        'top1000_voters_rating', 'top1000_voters_votes', 'us_voters_rating',
#        'us_voters_votes', 'non_us_voters_rating', 'non_us_voters_votes'],
#       dtype='object')

# %%
len(imbd_movies)
# Out:
# 85855

# %%
len(imbd_ratings)
# Out:
# 85855

# %% [markdown]
# len pada imbd_movies dan imbd_ratings sama dan memungkinkan untuk menggabungkan keduanya

# %%
imbd_movie_ratings =imbd_movies.merge(imbd_ratings, on='imdb_title_id')

# %%
#
imbd_movie_ratings = imbd_movie_ratings.fillna(0)

# %%
imbd_movie_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85855 entries, 0 to 85854
# Data columns (total 70 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   imdb_title_id              85855 non-null  object
#  1   title                      85855 non-null  object
#  2   original_title             85855 non-null  object
#  3   year                       85855 non-null  object
#  4   date_published             85855 non-null  object
#  5   genre                      85855 non-null  object
#  6   duration                   85855 non-null  int64
#  7   country                    85855 non-null  object
#  8   language                   85855 non-null  object
#  9   director                   85855 non-null  object
#  10  writer                     85855 non-null  object
#  11  production_company         85855 non-null  object
#  12  actors                     85855 non-null  object
#  13  description                85855 non-null  object
#  14  avg_vote                   85855 non-null  float64
#  15  votes                      85855 non-null  int64
#  16  budget                     85855 non-null  object
#  17  usa_gross_income           85855 non-null  object
#  18  worlwide_gross_income      85855 non-null  object
#  19  metascore                  85855 non-null  float64
#  20  reviews_from_users         85855 non-null  float64
#  21  reviews_from_critics       85855 non-null  float64
#  22  weighted_average_vote      85855 non-null  float64
#  23  total_votes                85855 non-null  int64
#  24  mean_vote                  85855 non-null  float64
#  25  median_vote                85855 non-null  float64
#  26  votes_10                   85855 non-null  int64
#  27  votes_9                    85855 non-null  int64
#  28  votes_8                    85855 non-null  int64
#  29  votes_7                    85855 non-null  int64
#  30  votes_6                    85855 non-null  int64
#  31  votes_5                    85855 non-null  int64
#  32  votes_4                    85855 non-null  int64
#  33  votes_3                    85855 non-null  int64
#  34  votes_2                    85855 non-null  int64
#  35  votes_1                    85855 non-null  int64
#  36  allgenders_0age_avg_vote   85855 non-null  float64
#  37  allgenders_0age_votes      85855 non-null  float64
#  38  allgenders_18age_avg_vote  85855 non-null  float64
#  39  allgenders_18age_votes     85855 non-null  float64
#  40  allgenders_30age_avg_vote  85855 non-null  float64
#  41  allgenders_30age_votes     85855 non-null  float64
#  42  allgenders_45age_avg_vote  85855 non-null  float64
#  43  allgenders_45age_votes     85855 non-null  float64
#  44  males_allages_avg_vote     85855 non-null  float64
#  45  males_allages_votes        85855 non-null  float64
#  46  males_0age_avg_vote        85855 non-null  float64
#  47  males_0age_votes           85855 non-null  float64
#  48  males_18age_avg_vote       85855 non-null  float64
#  49  males_18age_votes          85855 non-null  float64
#  50  males_30age_avg_vote       85855 non-null  float64
#  51  males_30age_votes          85855 non-null  float64
#  52  males_45age_avg_vote       85855 non-null  float64
#  53  males_45age_votes          85855 non-null  float64
#  54  females_allages_avg_vote   85855 non-null  float64
#  55  females_allages_votes      85855 non-null  float64
#  56  females_0age_avg_vote      85855 non-null  float64
#  57  females_0age_votes         85855 non-null  float64
#  58  females_18age_avg_vote     85855 non-null  float64
#  59  females_18age_votes        85855 non-null  float64
#  60  females_30age_avg_vote     85855 non-null  float64
#  61  females_30age_votes        85855 non-null  float64
#  62  females_45age_avg_vote     85855 non-null  float64
#  63  females_45age_votes        85855 non-null  float64
#  64  top1000_voters_rating      85855 non-null  float64
#  65  top1000_voters_votes       85855 non-null  float64
#  66  us_voters_rating           85855 non-null  float64
#  67  us_voters_votes            85855 non-null  float64
#  68  non_us_voters_rating       85855 non-null  float64
#  69  non_us_voters_votes        85855 non-null  float64
# dtypes: float64(41), int64(13), object(16)
# memory usage: 46.5+ MB

# %% [markdown]
# untuk melihat rata rata tertimbang untuk setiap jenis kelamin dan kolom allgenders,male,female dan age yang sesuai (jika ada satu)

# %%
def weighted_averages(x):
    number = x[0]
    avg = x[1]
    if number != 0.0:
        return ((number/(number+1000))*avg) + ((1000/(number+1000))*5.9)
    else:
        return 0

votes_per_group = []
# mengambil kolom yang diakhiri age_votes 
for column in imbd_movie_ratings.columns:
    if column.isnumeric and 'age' in column and 'votes' in column:
        votes_per_group.append(column)
        
avg_votes_per_group = []
# mengambil kolom yang diakhiri age_avg_vote
for column in imbd_movie_ratings.columns:
    if column.isnumeric and 'age' in column and 'avg_vote' in column:
        avg_votes_per_group.append(column)

# buat kolom imdb_movie_ratings DataFrame
for i in votes_per_group:
    imbd_movie_ratings['weighted_' + str(i)] = ''
    
tuple_list = []

for x in range(0,len(votes_per_group)):
    tuple_list.append((votes_per_group[x],avg_votes_per_group[x]))
    
# menerapkan fungsi weighted_avergaes function diatas
for votes, avg_votes in tuple_list:
    imbd_movie_ratings.loc[:,'weighted_' + votes] = imbd_movie_ratings[[votes,avg_votes]].apply(weighted_averages,axis=1)
    
imbd_movie_ratings.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2        0                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#   weighted_males_allages_votes weighted_males_0age_votes  \
# 0                     5.926527                  5.901099
# 1                     5.959649                  5.900100
# 2                     5.900000                  0.000000
# 3                     5.715858                  0.000000
# 4                     6.578059                  5.904192
#
#   weighted_males_18age_votes weighted_males_30age_votes  \
# 0                   5.900000                   5.889575
# 1                   5.927768                   5.917355
# 2                   5.891773                   5.900000
# 3                   5.886275                   5.812409
# 4                   6.182764                   6.390244
#
#    weighted_males_45age_votes  weighted_females_allages_votes  \
# 0                    5.924054                        5.903382
# 1                    5.927273                        5.914286
# 2                    5.915640                        5.897044
# 3                    5.797780                        5.900000
# 4                    6.212034                        6.130041
#
#   weighted_females_0age_votes weighted_females_18age_votes  \
# 0                    5.904187                     5.900000
# 1                    0.000000                     5.900000
# 2                    0.000000                     5.899602
# 3                    0.000000                     5.899402
# 4                    5.902196                     5.954373
#
#   weighted_females_30age_votes  weighted_females_45age_votes
# 0                     5.897433                      5.894422
# 1                     5.906745                      5.909665
# 2                     5.899602                      5.906256
# 3                     5.894477                      5.904114
# 4                     6.006100                      6.007242
#
# [5 rows x 84 columns]

# %%
#membuat variabel baru yaitu final_df dengan menggabungkan data dari netflix (netflix_titles) dan IMDb data (imbd_movie_ratings)
final_df = netflix_titles.merge(imbd_movie_ratings, how = 'inner', left_on=['title', 'year'], right_on=['title', 'year'])

# %%
final_df.head()
# Out:
#     type     title      country_x  year imdb_title_id original_title  \
# 0  Movie     23:59      Singapore  2011     tt2100376          23:59
# 1  Movie         9  United States  2009     tt0472033              9
# 2  Movie        21  United States  2008     tt0478087             21
# 3  Movie      1920          India  2008     tt1301698           1920
# 4  Movie  Æon Flux  United States  2005     tt0402022       Æon Flux
#
#   date_published                         genre  duration  \
# 0     2011-11-03                        Horror        78
# 1     2009-09-09  Animation, Action, Adventure        79
# 2     2008-04-18         Crime, Drama, History       123
# 3     2008-09-12      Horror, Mystery, Romance       138
# 4     2006-02-24     Action, Adventure, Sci-Fi        93
#
#                      country_y  ... weighted_males_allages_votes  \
# 0                    Singapore  ...                     5.421659
# 1                          USA  ...                     6.988049
# 2                          USA  ...                     6.794374
# 3                        India  ...                     6.233666
# 4  USA, Germany, Brazil, Italy  ...                     5.405627
#
#   weighted_males_0age_votes weighted_males_18age_votes  \
# 0                  5.895105                   5.776147
# 1                  5.960399                   7.041855
# 2                  5.918041                   6.973781
# 3                  5.904096                   6.166667
# 4                  5.875248                   5.440994
#
#   weighted_males_30age_votes weighted_males_45age_votes  \
# 0                   5.646372                   5.693849
# 1                   6.980945                   7.004966
# 2                   6.691813                   6.556476
# 3                   6.100100                   5.825953
# 4                   5.310312                   5.711280
#
#   weighted_females_allages_votes  weighted_females_0age_votes  \
# 0                       5.795048                     0.000000
# 1                       7.136228                     5.916568
# 2                       6.867851                     5.910704
# 3                       5.934025                     0.000000
# 4                       5.806063                     5.904382
#
#    weighted_females_18age_votes weighted_females_30age_votes  \
# 0                      5.847449                     5.864440
# 1                      7.104086                     7.089831
# 2                      6.997119                     6.747093
# 3                      5.927410                     5.891158
# 4                      5.900000                     5.719010
#
#   weighted_females_45age_votes
# 0                     5.878035
# 1                     6.711645
# 2                     6.518838
# 3                     5.908738
# 4                     5.900000
#
# [5 rows x 86 columns]

# %%
#mengecek apakah ada data yang hilang
print(final_df.isnull().sum().to_string())
# Out:
# type                               0
# title                              0
# country_x                          4
# year                               0
# imdb_title_id                      0
# original_title                     0
# date_published                     0
# genre                              0
# duration                           0
# country_y                          0
# language                           0
# director                           0
# writer                             0
# production_company                 0
# actors                             0
# description                        0
# avg_vote                           0
# votes                              0
# budget                             0
# usa_gross_income                   0
# worlwide_gross_income              0
# metascore                          0
# reviews_from_users                 0
# reviews_from_critics               0
# weighted_average_vote              0
# total_votes                        0
# mean_vote                          0
# median_vote                        0
# votes_10                           0
# votes_9                            0
# votes_8                            0
# votes_7                            0
# votes_6                            0
# votes_5                            0
# votes_4                            0
# votes_3                            0
# votes_2                            0
# votes_1                            0
# allgenders_0age_avg_vote           0
# allgenders_0age_votes              0
# allgenders_18age_avg_vote          0
# allgenders_18age_votes             0
# allgenders_30age_avg_vote          0
# allgenders_30age_votes             0
# allgenders_45age_avg_vote          0
# allgenders_45age_votes             0
# males_allages_avg_vote             0
# males_allages_votes                0
# males_0age_avg_vote                0
# males_0age_votes                   0
# males_18age_avg_vote               0
# males_18age_votes                  0
# males_30age_avg_vote               0
# males_30age_votes                  0
# males_45age_avg_vote               0
# males_45age_votes                  0
# females_allages_avg_vote           0
# females_allages_votes              0
# females_0age_avg_vote              0
# females_0age_votes                 0
# females_18age_avg_vote             0
# females_18age_votes                0
# females_30age_avg_vote             0
# females_30age_votes                0
# females_45age_avg_vote             0
# females_45age_votes                0
# top1000_voters_rating              0
# top1000_voters_votes               0
# us_voters_rating                   0
# us_voters_votes                    0
# non_us_voters_rating               0
# non_us_voters_votes                0
# weighted_allgenders_0age_votes     0
# weighted_allgenders_18age_votes    0
# weighted_allgenders_30age_votes    0
# weighted_allgenders_45age_votes    0
# weighted_males_allages_votes       0
# weighted_males_0age_votes          0
# weighted_males_18age_votes         0
# weighted_males_30age_votes         0
# weighted_males_45age_votes         0
# weighted_females_allages_votes     0
# weighted_females_0age_votes        0
# weighted_females_18age_votes       0
# weighted_females_30age_votes       0
# weighted_females_45age_votes       0

# %%
#melihat data yang hilang
final_df[final_df['country_x'].isnull()]
# Out:
#       type                         title country_x  year imdb_title_id  \
# 6    Movie                   3 Deewarein       NaN  2003     tt0338490
# 74   Movie                  Been So Long       NaN  2018     tt1682886
# 262  Movie  Jis Desh Men Ganga Behti Hai       NaN  1960     tt0053965
# 508  Movie                   Tanda Tanya       NaN  2011     tt1979169
#
#                    original_title date_published                    genre  \
# 6                     3 Deewarein     2003-08-01             Crime, Drama
# 74                   Been So Long     2018-10-26  Drama, Musical, Romance
# 262  Jis Desh Men Ganga Behti Hai           1960  Drama, Musical, Romance
# 508                   Tanda Tanya     2011-04-07                    Drama
#
#      duration  country_y  ... weighted_males_allages_votes  \
# 6         115      India  ...                     7.085177
# 74        100          0  ...                     5.688600
# 262       167      India  ...                     6.152881
# 508       100  Indonesia  ...                     6.013453
#
#     weighted_males_0age_votes weighted_males_18age_votes  \
# 6                    0.000000                   6.248980
# 74                   5.899202                   5.865116
# 262                  0.000000                   5.951252
# 508                  0.000000                   5.952772
#
#     weighted_males_30age_votes weighted_males_45age_votes  \
# 6                     7.007939                   5.925632
# 74                    5.793655                   5.803956
# 262                   6.110232                   5.867108
# 508                   5.954820                   5.897015
#
#     weighted_females_allages_votes  weighted_females_0age_votes  \
# 6                         6.182979                     0.000000
# 74                        5.900000                     5.888335
# 262                       5.994269                     0.000000
# 508                       5.935680                     0.000000
#
#      weighted_females_18age_votes weighted_females_30age_votes  \
# 6                        5.930059                     6.081295
# 74                       5.892678                     5.878891
# 262                      5.915164                     5.970817
# 508                      5.922483                     5.916683
#
#     weighted_females_45age_votes
# 6                       5.971014
# 74                      5.916123
# 262                     5.904950
# 508                     5.898102
#
# [4 rows x 86 columns]

# %%
final_df.loc[6,'country_x'] = 'India'
final_df.loc[74,'country_x'] = 'United Kingdom'
final_df.loc[262,'country_x'] = 'India'
final_df.loc[508,'country_x'] = 'Indonesia'

# %%
final_df[final_df['country_x'].isnull()]
# Out:
# Empty DataFrame
# Columns: [type, title, country_x, year, imdb_title_id, original_title, date_published, genre, duration, country_y, language, director, writer, production_company, actors, description, avg_vote, votes, budget, usa_gross_income, worlwide_gross_income, metascore, reviews_from_users, reviews_from_critics, weighted_average_vote, total_votes, mean_vote, median_vote, votes_10, votes_9, votes_8, votes_7, votes_6, votes_5, votes_4, votes_3, votes_2, votes_1, allgenders_0age_avg_vote, allgenders_0age_votes, allgenders_18age_avg_vote, allgenders_18age_votes, allgenders_30age_avg_vote, allgenders_30age_votes, allgenders_45age_avg_vote, allgenders_45age_votes, males_allages_avg_vote, males_allages_votes, males_0age_avg_vote, males_0age_votes, males_18age_avg_vote, males_18age_votes, males_30age_avg_vote, males_30age_votes, males_45age_avg_vote, males_45age_votes, females_allages_avg_vote, females_allages_votes, females_0age_avg_vote, females_0age_votes, females_18age_avg_vote, females_18age_votes, females_30age_avg_vote, females_30age_votes, females_45age_avg_vote, females_45age_votes, top1000_voters_rating, top1000_voters_votes, us_voters_rating, us_voters_votes, non_us_voters_rating, non_us_voters_votes, weighted_allgenders_0age_votes, weighted_allgenders_18age_votes, weighted_allgenders_30age_votes, weighted_allgenders_45age_votes, weighted_males_allages_votes, weighted_males_0age_votes, weighted_males_18age_votes, weighted_males_30age_votes, weighted_males_45age_votes, weighted_females_allages_votes, weighted_females_0age_votes, weighted_females_18age_votes, weighted_females_30age_votes, weighted_females_45age_votes, country]
# Index: []
#
# [0 rows x 87 columns]

# %% [markdown]
# # TOP RATED MOVIES

# %% [markdown]
# film film rating tinggi secara keseluruhan dan berdasarkan laki laki dan wanita

# %%
def plot_data(col_name, graph_title, xlabel = 'Rating'):
    
    rating = final_df[[col_name]].loc[:, col_name].sort_values(ascending=False).head(10).values
    index = final_df[[col_name]].loc[:, col_name].sort_values(ascending=False).index[:10]

    sns.set_context('poster')
    sns.set(rc={'figure.figsize':(10,8)})
    sns.set_style('darkgrid')

    fig, ax = plt.subplots()
    title = []

    for i in index:
        title.append(final_df.loc[i, 'title'])

    y_pos = np.arange(len(title))

    ratings = []
    for r in rating:
        ratings.append(r)

    ax.barh(y_pos, ratings, edgecolor='black',color=('#0094FD','#1BA1FF','#37ACFF','#63BEFE',
                                                     '#83CBFD','#A6DAFF','#C2E5FF','#D7EEFF','#E6F4FF','#F5FBFF'))
    ax.set_yticks(y_pos)
    ax.set_yticklabels(title, fontsize=15)
    ax.invert_yaxis()
    ax.set_xlabel(xlabel, fontsize=15)
    ax.set_ylabel('Movie', fontsize=15)
    ax.set_title(graph_title, fontsize=20)


    plt.show()

# %%
plot_data('weighted_average_vote', 'Top 10 Weighted Movies on Netlfix')

# %%
plot_data('weighted_females_allages_votes', 'Top 10 Weighted oleh Wanita Movies on Netlfix')

# %%
plot_data('weighted_males_allages_votes', 'Top 10 Weighted oleh Pria Movies on Netflix')

# %% [markdown]
# # Top Rated Movies Berdasarkan Genre

# %%
def plot_data_genre(genre_name, graph_title, xlabel = 'Rating'):
    
    final_df[genre_name] = ''
    for i in range(0, len(final_df)):
        if genre_name in final_df.loc[i].genre:
            final_df.loc[i,genre_name] = 1
        else:
            final_df.loc[i,genre_name] = 0
            
    df = final_df[final_df[genre_name] == 1]
    
    rating = df[['weighted_average_vote']].loc[:, 'weighted_average_vote'].sort_values(ascending=False).head(10).values
    index = df[['weighted_average_vote']].loc[:, 'weighted_average_vote'].sort_values(ascending=False).index[:10]

    sns.set_context('poster')
    sns.set(rc={'figure.figsize':(10,8)})
    sns.set_style('darkgrid')

    fig, ax = plt.subplots()
    title = []

    for i in index:
        title.append(final_df.loc[i, 'title'])

    y_pos = np.arange(len(title))

    ratings = []
    for r in rating:
        ratings.append(r)

    ax.barh(y_pos, ratings, edgecolor='black',color=('#0094FD','#1BA1FF','#37ACFF','#63BEFE',
                                                     '#83CBFD','#A6DAFF','#C2E5FF','#D7EEFF','#E6F4FF','#F5FBFF'))
    ax.set_yticks(y_pos)
    ax.set_yticklabels(title, fontsize=15)
    ax.invert_yaxis()
    ax.set_xlabel(xlabel, fontsize=15)
    ax.set_ylabel('Movie', fontsize=15)
    ax.set_title(graph_title, fontsize=20)


    plt.show()

# %%
plot_data_genre('Drama', 'Top Weighted Drama Movies on Netflix')

# %%
plot_data_genre('Comedy', 'Top Weighted Comedy Movies on Netflix')

# %%
plot_data_genre('Action', 'Top Weighted Action Movies on Netflix')

# %%
plot_data_genre('Romance', 'Top Weighted Romance Movies on Netflix')

# %%
plot_data_genre('Thriller', 'Top Weighted Thriller Movies on Netflix')

# %% [markdown]
# # Top Rated Movies Berdasarkan Release Year

# %%
def plot_release_year(release_year, graph_title, xlabel = 'Rating'):
            
    df = final_df[final_df['year'] == release_year]
    
    rating = df[['weighted_average_vote']].loc[:, 'weighted_average_vote'].sort_values(ascending=False).head(10).values
    index = df[['weighted_average_vote']].loc[:, 'weighted_average_vote'].sort_values(ascending=False).index[:10]

    sns.set_context('poster')
    sns.set(rc={'figure.figsize':(10,8)})
    sns.set_style('darkgrid')

    fig, ax = plt.subplots()
    title = []

    for i in index:
        title.append(final_df.loc[i, 'title'])

    y_pos = np.arange(len(title))

    ratings = []
    for r in rating:
        ratings.append(r)

    ax.barh(y_pos, ratings, edgecolor='black',color=('#0094FD','#1BA1FF','#37ACFF','#63BEFE',
                                                     '#83CBFD','#A6DAFF','#C2E5FF','#D7EEFF','#E6F4FF','#F5FBFF'))
    ax.set_yticks(y_pos)
    ax.set_yticklabels(title, fontsize=15)
    ax.invert_yaxis()
    ax.set_xlabel(xlabel, fontsize=15)
    ax.set_ylabel('Movie', fontsize=15)
    ax.set_title(graph_title, fontsize=20)

    plt.show()

# %%
plot_release_year(2020,'Top Rated Movies Released in 2020')

# %%
plot_release_year(2019,'Top Rated Movies Released in 2019')

# %%
plot_release_year(2018,'Top Rated Movies Released in 2018')

# %%
plot_release_year(2015,'Top Rated Movies Released in 2015')
